# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
##split the data
train, test = train_test_split(data, test_size=0.25, random_state=42)
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    #conduct hyper param search
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/3
#
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 33.9943 - root_mean_squared_error: 5.2666
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 35.2740 - root_mean_squared_error: 5.2666
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 32.8217 - root_mean_squared_error: 5.2666
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 30.7449 - root_mean_squared_error: 5.2666
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - loss: 36.1661 - root_mean_squared_error: 5.2666
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 29.7695 - root_mean_squared_error: 5.1837
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 31.7384 - root_mean_squared_error: 5.1837
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - loss: 27.1325 - root_mean_squared_error: 5.1837
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 4.1346 - root_mean_squared_error: 2.0333
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - loss: 34.6473 - root_mean_squared_error: 5.8865
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 34.6507 - root_mean_squared_error: 5.8363
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 34.0675 - root_mean_squared_error: 5.8363
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 33.1162 - root_mean_squared_error: 5.7525
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 31.9988 - root_mean_squared_error: 5.6514
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.9693 - root_mean_squared_error: 3.4617 - val_loss: 1.2363 - val_root_mean_squared_error: 1.1119
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8980 - root_mean_squared_error: 0.9539
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.9100 - root_mean_squared_error: 0.9539
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.9606 - root_mean_squared_error: 0.9909
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.9833 - root_mean_squared_error: 0.9909
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.9918 - root_mean_squared_error: 0.9954
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 0.9919 - root_mean_squared_error: 0.9954
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.9992 - root_mean_squared_error: 0.9991
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 1.0049 - root_mean_squared_error: 1.0023 - val_loss: 0.8748 - val_root_mean_squared_error: 0.9353
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8109 - root_mean_squared_error: 0.8782
#  2/46 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.7717 - root_mean_squared_error: 0.8782
#  3/46 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 0.7314 - root_mean_squared_error: 0.8493
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.7208 - root_mean_squared_error: 0.8536
#  7/46 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.7294 - root_mean_squared_error: 0.8561
#  6/46 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.7221 - root_mean_squared_error: 0.8536
#  4/46 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.7225 - root_mean_squared_error: 0.8536
#  8/46 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.7336 - root_mean_squared_error: 0.8561
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 0.7349 - root_mean_squared_error: 0.8569
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.7368 - root_mean_squared_error: 0.8594
# 10/46 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.7361 - root_mean_squared_error: 0.8581
# 13/46 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.7405 - root_mean_squared_error: 0.8602
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 0.7392 - root_mean_squared_error: 0.8602
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7452 - root_mean_squared_error: 0.8632 - val_loss: 0.7222 - val_root_mean_squared_error: 0.8498
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6077 - root_mean_squared_error: 0.7750
#  2/12 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 0.6006 - root_mean_squared_error: 0.7750
#  3/12 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.6418 - root_mean_squared_error: 0.8084
#  4/12 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.6546 - root_mean_squared_error: 0.8084
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.7095 - root_mean_squared_error: 0.8417
#
# 100%|██████████| 4/4 [00:08<00:00,  2.15s/trial, best loss: 0.748021125793457]
# Best parameters: {'lr': 0.02839506243081091, 'momentum': 0.37980466286576053}
# Best eval rmse: 0.748021125793457
